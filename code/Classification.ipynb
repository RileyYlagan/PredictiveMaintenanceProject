# %%
# !pip install shap
from google.colab import drive 
import shap
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
#bringing in data
drive.mount('/content/gdrive')
df = pd.read_csv("gdrive/My Drive/clean_data_final.csv")
df.head()
# Out:
# Requirement already satisfied: shap in /usr/local/lib/python3.7/dist-packages (0.40.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from shap) (1.19.5)
# Requirement already satisfied: packaging>20.9 in /usr/local/lib/python3.7/dist-packages (from shap) (21.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from shap) (1.1.5)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.7/dist-packages (from shap) (1.3.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from shap) (1.0.1)
# Requirement already satisfied: slicer==0.0.7 in /usr/local/lib/python3.7/dist-packages (from shap) (0.0.7)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from shap) (1.4.1)
# Requirement already satisfied: tqdm>4.25.0 in /usr/local/lib/python3.7/dist-packages (from shap) (4.62.3)
# Requirement already satisfied: numba in /usr/local/lib/python3.7/dist-packages (from shap) (0.51.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>20.9->shap) (3.0.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba->shap) (57.4.0)
# Requirement already satisfied: llvmlite<0.35,>=0.34.0.dev0 in /usr/local/lib/python3.7/dist-packages (from numba->shap) (0.34.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->shap) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->shap) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->shap) (1.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->shap) (3.0.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->shap) (1.1.0)
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
#    UID Product.ID Type  ...  Tool.wear..min.  Machine.failure  Failure.type
# 0    1     M14860    M  ...                0                0          NONE
# 1    2     L47181    L  ...                3                0          NONE
# 2    3     L47182    L  ...                5                0          NONE
# 3    4     L47183    L  ...                7                0          NONE
# 4    5     L47184    L  ...                9                0          NONE
#
# [5 rows x 10 columns]

# %%
#balance the dataset
df = df.drop(df[df['Machine.failure'] == 0].sample(frac=.96).index) #balancing the dataset
feature_names = df.columns[4:8]
print(feature_names)
df.head()
# Out:
# Index(['Process.temperature..K.', 'Rotational.speed..rpm.', 'Torque..Nm.',
#        'Tool.wear..min.'],
#       dtype='object')
#     UID Product.ID Type  ...  Tool.wear..min.  Machine.failure  Failure.type
# 1     2     L47181    L  ...                3                0          NONE
# 33   34     L47213    L  ...               93                0          NONE
# 42   43     M14902    M  ...              117                0          NONE
# 50   51     L47230    L  ...              143                1           PWF
# 69   70     L47249    L  ...              191                1           PWF
#
# [5 rows x 10 columns]

# %%
plt.plot(df["Air.temperature..K."])
print("Variance: ", df["Air.temperature..K."].var())
# Out:
# Variance:  4.439418973629475

# %%
#checking balance
healthy_ct = 0
fail_ct = 0
for cell in df["Machine.failure"]:
    if cell == 0:
        healthy_ct += 1
    else:
        fail_ct += 1
print("Fail Ct: ", fail_ct)
print('Healthy Ct: ', healthy_ct)


pwf = 0
osf = 0
twf = 0
hdf = 0
none = 0
for cell in df["Failure.type"]:
    if cell == "PWF":
        pwf += 1
    elif cell == "OSF":
        osf += 1
    elif cell == "TWF":
        twf += 1
    elif cell == "HDF":
        hdf += 1
    else:
        none += 1
print()
print("TWF: ", twf)
print("PWF: ", pwf)
print("OSF: ", osf)
print("HDF: ", hdf)
print("None: ", none)
# Out:
# Fail Ct:  355
# Healthy Ct:  386
#
# TWF:  46
# PWF:  95
# OSF:  98
# HDF:  115
# None:  387

# %%
#train test split time
from sklearn.model_selection import train_test_split
#TWF
X_features = df.iloc[:,4:8]
y = df[["Failure.type"]]

x_train, x_test, y_train, y_test = train_test_split(X_features, y, test_size = 0.3)

# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, plot_confusion_matrix
import seaborn as sns

def get_best_depth(train_x,train_y,test_x,test_y):
    x,y = [], []
    for i in range(1,50):
        dtc = DecisionTreeClassifier(max_depth = i).fit(train_x, train_y)
        dtc_pred = dtc.predict(test_x)
        val = accuracy_score(dtc_pred, test_y)
        x.append(val)
        y.append(i)
        index_max = max(range(len(x)), key=x.__getitem__) + 1
    return x, y, index_max

store, indices, depth = get_best_depth(x_train, y_train,x_test, y_test)

plt.plot(indices, store, marker = 'o', linestyle = '--')
plt.title("Accuracy over Depth")
plt.ylabel("Accuracy Score")
plt.xlabel("Depth Size")



dtc_final = DecisionTreeClassifier().fit(x_train, y_train)
dtc_final_pred = dtc_final.predict(x_test)
print("Accuracy Score: ", accuracy_score(dtc_final_pred, y_test)*100, "%")
# Out:
# Accuracy Score:  78.9237668161435 %

# %%
plt.figure(figsize = (25,25))
plot_tree(dtc_final, class_names = list(df["Failure.type"]), feature_names = list(feature_names), fontsize = 8)
plt.savefig('tree.jpg',format='jpg')

# %%
#built the whole tree but lets check for twf only
twf = df[(df["Failure.type"] == "TWF") | (df["Failure.type"] == "NONE")]
twf = twf.drop(twf[twf['Failure.type'] == "NONE"].sample(frac=.85).index)
y_twf = twf["Failure.type"]
x_twf = twf.iloc[:,4:8]


x_twf_train, x_twf_test, y_twf_train, y_twf_test = train_test_split(x_twf, y_twf, test_size = 0.3)

twf_store, twf_indices, twf_depth = get_best_depth(x_twf_train, y_twf_train,x_twf_test, y_twf_test)
# plt.plot(twf_indices, twf_store, marker = 'o', linestyle = '--')
# plt.title('Accuracy v Depth - TWF')
# plt.xlabel('Depth')
# plt.ylabel('Accuracy Score')
twf_clf = DecisionTreeClassifier().fit(x_twf_train, y_twf_train)

#model accuracy
twf_pred = twf_clf.predict(x_twf_test)
print("Accuracy Score: ", accuracy_score(twf_pred, y_twf_test) * 100, "%")
# none, t = 0, 0
# for cell in twf["Failure.type"]:
#     if cell == "NONE":
#         none += 1
#     else:
#         t += 1
# print(none, t)
# Out:
# Accuracy Score:  90.625 %

# %%
plt.figure(figsize = (30,30))
plot_tree(twf_clf, class_names = list(y_twf), feature_names = list(feature_names), fontsize = 8)
# Out:
# [Text(930.0, 1540.2, 'Tool.wear..min. <= 197.5\ngini = 0.49\nsamples = 72\nvalue = [41, 31]\nclass = TWF'),
#  Text(744.0, 1359.0, 'gini = 0.0\nsamples = 35\nvalue = [35, 0]\nclass = TWF'),
#  Text(1116.0, 1359.0, 'Rotational.speed..rpm. <= 1469.0\ngini = 0.272\nsamples = 37\nvalue = [6, 31]\nclass = NONE'),
#  Text(930.0, 1177.8, 'gini = 0.0\nsamples = 11\nvalue = [0, 11]\nclass = NONE'),
#  Text(1302.0, 1177.8, 'Torque..Nm. <= 39.15\ngini = 0.355\nsamples = 26\nvalue = [6, 20]\nclass = NONE'),
#  Text(1116.0, 996.6, 'Process.temperature..K. <= 310.1\ngini = 0.227\nsamples = 23\nvalue = [3, 20]\nclass = NONE'),
#  Text(930.0, 815.4, 'Process.temperature..K. <= 309.9\ngini = 0.397\nsamples = 11\nvalue = [3, 8]\nclass = NONE'),
#  Text(744.0, 634.2, 'Rotational.speed..rpm. <= 1829.5\ngini = 0.32\nsamples = 10\nvalue = [2, 8]\nclass = NONE'),
#  Text(558.0, 453.0, 'Torque..Nm. <= 34.15\ngini = 0.444\nsamples = 6\nvalue = [2, 4]\nclass = NONE'),
#  Text(372.0, 271.79999999999995, 'Rotational.speed..rpm. <= 1549.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = TWF'),
#  Text(186.0, 90.60000000000014, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = NONE'),
#  Text(558.0, 90.60000000000014, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = TWF'),
#  Text(744.0, 271.79999999999995, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = NONE'),
#  Text(930.0, 453.0, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = NONE'),
#  Text(1116.0, 634.2, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = TWF'),
#  Text(1302.0, 815.4, 'gini = 0.0\nsamples = 12\nvalue = [0, 12]\nclass = NONE'),
#  Text(1488.0, 996.6, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = TWF')]

# %%
pwf = df[(df["Failure.type"] == "PWF") | (df["Failure.type"] == "NONE")]
pwf = pwf.drop(pwf[pwf['Failure.type'] == "NONE"].sample(frac=.75).index)
y_pwf = pwf["Failure.type"]
x_pwf = pwf.iloc[:,4:8]

x_pwf_train, x_pwf_test, y_pwf_train, y_pwf_test = train_test_split(x_pwf, y_pwf, test_size = 0.3)

pwf_store, pwf_indices, pwf_depth = get_best_depth(x_pwf_train, y_pwf_train, x_pwf_test, y_pwf_test)
# plt.plot(pwf_indices, pwf_store, marker = 'o', linestyle = '--')
# plt.title("Accuracy v Depth - PWF")
# plt.ylabel("Accuracy")
# plt.xlabel("Depth")

dtc_pwf = DecisionTreeClassifier(max_depth = pwf_depth).fit(x_pwf_train, y_pwf_train)
dtc_pwf_pred = dtc_pwf.predict(x_pwf_test)
print("Accuracy Score: ", accuracy_score(dtc_pwf_pred, y_pwf_test) * 100, "%")

# none, t = 0, 0
# for cell in pwf["Failure.type"]:
#     if cell == "NONE":
#         none += 1
#     else:
#         t += 1
# print(none, t)
# Out:
# Accuracy Score:  100.0 %

# %%
plot_tree(dtc_pwf, class_names = list(dtc_pwf.classes_), feature_names = list(feature_names), fontsize = 8)
# Out:
# [Text(167.4, 181.2, 'Torque..Nm. <= 56.8\ngini = 0.5\nsamples = 133\nvalue = [68, 65]\nclass = NONE'),
#  Text(83.7, 108.72, 'Rotational.speed..rpm. <= 2084.0\ngini = 0.334\nsamples = 85\nvalue = [67, 18]\nclass = NONE'),
#  Text(41.85, 36.23999999999998, 'gini = 0.0\nsamples = 67\nvalue = [67, 0]\nclass = NONE'),
#  Text(125.55000000000001, 36.23999999999998, 'gini = 0.0\nsamples = 18\nvalue = [0, 18]\nclass = PWF'),
#  Text(251.10000000000002, 108.72, 'Torque..Nm. <= 62.15\ngini = 0.041\nsamples = 48\nvalue = [1, 47]\nclass = PWF'),
#  Text(209.25, 36.23999999999998, 'gini = 0.278\nsamples = 6\nvalue = [1, 5]\nclass = PWF'),
#  Text(292.95, 36.23999999999998, 'gini = 0.0\nsamples = 42\nvalue = [0, 42]\nclass = PWF')]

# %%
osf = df[(df["Failure.type"] == "OSF") | (df["Failure.type"] == "NONE")]
osf = osf.drop(osf[osf['Failure.type'] == "NONE"].sample(frac=.7).index)
y_osf = osf["Failure.type"]
x_osf = osf.iloc[:,4:8]

x_osf_train, x_osf_test, y_osf_train, y_osf_test = train_test_split(x_osf, y_osf, test_size = 0.3)

osf_store, osf_indices, osf_depth = get_best_depth(x_osf_train, y_osf_train, x_osf_test, y_osf_test)
# plt.plot(osf_indices, osf_store, marker = 'o', linestyle = '--')
# plt.title("Accuracy v Depth - OSF")
# plt.ylabel("Accuracy")
# plt.xlabel("Depth")

dtc_osf = DecisionTreeClassifier().fit(x_osf_train, y_osf_train)
dtc_osf_pred = dtc_osf.predict(x_osf_test)
print("Accuracy Score: ", accuracy_score(dtc_osf_pred, y_osf_test) * 100, "%")
# none, t = 0, 0
# for cell in osf["Failure.type"]:
#     if cell == "NONE":
#         none += 1
#     else:
#         t += 1
# print(none, t)
# Out:
# Accuracy Score:  98.46153846153847 %

# %%
plt.figure(figsize = (20,20))
plot_tree(dtc_osf, class_names = list(y_osf), feature_names = list(feature_names), fontsize = 8)
# Out:
# [Text(248.0, 1019.25, 'Tool.wear..min. <= 170.5\ngini = 0.499\nsamples = 149\nvalue = [77, 72]\nclass = OSF'),
#  Text(124.0, 883.35, 'gini = 0.0\nsamples = 64\nvalue = [64, 0]\nclass = OSF'),
#  Text(372.0, 883.35, 'Torque..Nm. <= 45.35\ngini = 0.259\nsamples = 85\nvalue = [13, 72]\nclass = NONE'),
#  Text(248.0, 747.45, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]\nclass = OSF'),
#  Text(496.0, 747.45, 'Process.temperature..K. <= 307.25\ngini = 0.077\nsamples = 75\nvalue = [3, 72]\nclass = NONE'),
#  Text(248.0, 611.55, 'Rotational.speed..rpm. <= 1377.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = OSF'),
#  Text(124.0, 475.65, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = NONE'),
#  Text(372.0, 475.65, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = OSF'),
#  Text(744.0, 611.55, 'Process.temperature..K. <= 309.7\ngini = 0.053\nsamples = 73\nvalue = [2, 71]\nclass = NONE'),
#  Text(620.0, 475.65, 'Process.temperature..K. <= 309.55\ngini = 0.172\nsamples = 21\nvalue = [2, 19]\nclass = NONE'),
#  Text(372.0, 339.75, 'Tool.wear..min. <= 198.5\ngini = 0.1\nsamples = 19\nvalue = [1, 18]\nclass = NONE'),
#  Text(248.0, 203.85000000000002, 'Torque..Nm. <= 57.9\ngini = 0.245\nsamples = 7\nvalue = [1, 6]\nclass = NONE'),
#  Text(124.0, 67.95000000000005, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = OSF'),
#  Text(372.0, 67.95000000000005, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]\nclass = NONE'),
#  Text(496.0, 203.85000000000002, 'gini = 0.0\nsamples = 12\nvalue = [0, 12]\nclass = NONE'),
#  Text(868.0, 339.75, 'Rotational.speed..rpm. <= 1471.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = OSF'),
#  Text(744.0, 203.85000000000002, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = OSF'),
#  Text(992.0, 203.85000000000002, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = NONE'),
#  Text(868.0, 475.65, 'gini = 0.0\nsamples = 52\nvalue = [0, 52]\nclass = NONE')]

# %%
hdf = df[(df["Failure.type"] == "HDF") | (df["Failure.type"] == "NONE")]
hdf = hdf.drop(hdf[hdf['Failure.type'] == "NONE"].sample(frac=.9).index)
y_hdf = hdf["Failure.type"]
x_hdf = hdf.iloc[:,4:8]

x_hdf_train, x_hdf_test, y_hdf_train, y_hdf_test = train_test_split(x_hdf, y_hdf, test_size = 0.3)

hdf_store, hdf_indices, hdf_depth = get_best_depth(x_hdf_train, y_hdf_train, x_hdf_test, y_hdf_test)
# plt.plot(hdf_indices, hdf_store, marker = 'o', linestyle = '--')
# plt.title("Accuracy v Depth - HDF")
# plt.ylabel("Accuracy")
# plt.xlabel("Depth")


dtc_hdf = DecisionTreeClassifier().fit(x_hdf_train, y_hdf_train)
dtc_hdf_pred = dtc_hdf.predict(x_hdf_test)
print("Accuracy Score: ", accuracy_score(dtc_hdf_pred, y_hdf_test) * 100, "%")


# none, t = 0, 0
# for cell in hdf["Failure.type"]:
#     if cell == "NONE":
#         none += 1
#     else:
#         t += 1
# print(none, t)
# Out:
# Accuracy Score:  97.87234042553192 %

# %%
plt.figure(figsize = (20,20))
plot_tree(dtc_hdf, class_names = list(y_hdf), feature_names = list(feature_names), fontsize = 8)
# Out:
# [Text(558.0, 996.6, 'Rotational.speed..rpm. <= 1380.5\ngini = 0.404\nsamples = 107\nvalue = [77, 30]\nclass = NONE'),
#  Text(372.0, 815.4000000000001, 'Process.temperature..K. <= 309.15\ngini = 0.094\nsamples = 81\nvalue = [77, 4]\nclass = NONE'),
#  Text(186.0, 634.2, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = NONE'),
#  Text(558.0, 634.2, 'Rotational.speed..rpm. <= 1365.5\ngini = 0.025\nsamples = 78\nvalue = [77, 1]\nclass = NONE'),
#  Text(372.0, 453.0, 'gini = 0.0\nsamples = 62\nvalue = [62, 0]\nclass = NONE'),
#  Text(744.0, 453.0, 'Rotational.speed..rpm. <= 1367.5\ngini = 0.117\nsamples = 16\nvalue = [15, 1]\nclass = NONE'),
#  Text(558.0, 271.79999999999995, 'Tool.wear..min. <= 118.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = NONE'),
#  Text(372.0, 90.59999999999991, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = NONE'),
#  Text(744.0, 90.59999999999991, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = NONE'),
#  Text(930.0, 271.79999999999995, 'gini = 0.0\nsamples = 13\nvalue = [13, 0]\nclass = NONE'),
#  Text(744.0, 815.4000000000001, 'gini = 0.0\nsamples = 26\nvalue = [0, 26]\nclass = NONE')]

# %%
from sklearn.calibration import calibration_curve

prob_pos_pwf = dtc_pwf.predict_proba(x_pwf_test)[:,1]
prob_pos_twf = twf_clf.predict_proba(x_twf_test)[:,1]
prob_pos_osf = dtc_osf.predict_proba(x_osf_test)[:,1]
prob_pos_hdf = dtc_hdf.predict_proba(x_hdf_test)[:,1]



frac_pos_pwf, mean_pred_pwf = calibration_curve(y_pwf_test, prob_pos_pwf)
frac_pos_twf, mean_pred_twf = calibration_curve(y_twf_test, prob_pos_twf)
frac_pos_osf, mean_pred_osf = calibration_curve(y_osf_test, prob_pos_osf)
frac_pos_hdf, mean_pred_hdf = calibration_curve(y_hdf_test, prob_pos_hdf)



plt.plot([0, 1], [0, 1], "k:", label = "Perfect Calibration")
plt.plot(mean_pred_pwf, frac_pos_pwf, "s-", label = "PWF")
plt.plot(mean_pred_twf, frac_pos_twf, "s-", label = "TWF")
plt.plot(mean_pred_osf, frac_pos_osf, "s-", label = "OSF")
plt.plot(mean_pred_hdf, frac_pos_hdf, "s-", label = "HDF")
plt.legend()
plt.title("Prediction probability")
plt.xlabel("Predicted Probability")
plt.ylabel("Fraction of Positives")
# Out:
# Text(0, 0.5, 'Fraction of Positives')

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import export_graphviz

rand_forest_pure = RandomForestClassifier(n_estimators = depth).fit(x_train, y_train)
rand_forest_pure_pred = rand_forest_pure.predict(x_test)
print("RF Pure Acc: ", accuracy_score(rand_forest_pure_pred, y_test))


# Export as dot file
export_graphviz(dtc_final, out_file = 'tree.jpg', rounded = True, proportion = False, precision = 2, filled = True)
# Out:
# RF Pure Acc:  0.7982062780269058
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().

# %%
conf_matrix_pwf = plot_confusion_matrix(dtc_pwf, x_pwf_test, y_pwf_test)
conf_matrix_twf = plot_confusion_matrix(twf_clf, x_twf_test, y_twf_test)
conf_matrix_osf = plot_confusion_matrix(dtc_osf, x_osf_test, y_osf_test)
conf_matrix_hdf = plot_confusion_matrix(dtc_hdf, x_hdf_test, y_hdf_test)
conf_matrix_pure = plot_confusion_matrix(dtc_final, x_test, y_test)
# Out:
# Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
# Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
# Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
# Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
# Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.

# %%
#fail no fail model

y_plain = df[["Machine.failure"]]
x_plain = df.iloc[:,4:8]


x_plain_train, x_plain_test, y_plain_train, y_plain_test = train_test_split(x_plain, y_plain, test_size = 0.3)
plain_store, plain_indices, plain_depth = get_best_depth(x_plain_train, y_plain_train, x_plain_test, y_plain_test)
#acc v depth
plt.plot(plain_indices, plain_store, marker = 'o', linestyle = '--')


dtc_fnf = DecisionTreeClassifier(max_depth = plain_depth).fit(x_plain_train, y_plain_train)
plt.figure(figsize = (20,20))
plot_tree(dtc_fnf, class_names = ["Failed", "Healthy"],feature_names = list(["Air Temp","Process Temp", "Rotational Speed", "Torque", "Tool Wear"]) ,fontsize = 8, filled = True)
# Out:
# [Text(574.953125, 1037.7818181818182, 'Process Temp <= 1406.5\ngini = 0.499\nsamples = 518\nvalue = [270, 248]\nclass = Failed'),
#  Text(320.65625, 938.9454545454546, 'Rotational Speed <= 53.1\ngini = 0.314\nsamples = 231\nvalue = [45, 186]\nclass = Healthy'),
#  Text(133.6875, 840.1090909090909, 'Air Temp <= 309.8\ngini = 0.454\nsamples = 89\nvalue = [31, 58]\nclass = Healthy'),
#  Text(46.5, 741.2727272727273, 'Torque <= 201.0\ngini = 0.444\nsamples = 24\nvalue = [16, 8]\nclass = Failed'),
#  Text(31.0, 642.4363636363637, 'gini = 0.0\nsamples = 14\nvalue = [14, 0]\nclass = Failed'),
#  Text(62.0, 642.4363636363637, 'Process Temp <= 1399.5\ngini = 0.32\nsamples = 10\nvalue = [2, 8]\nclass = Healthy'),
#  Text(46.5, 543.6, 'Torque <= 211.5\ngini = 0.198\nsamples = 9\nvalue = [1, 8]\nclass = Healthy'),
#  Text(31.0, 444.76363636363635, 'Rotational Speed <= 47.55\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Healthy'),
#  Text(15.5, 345.9272727272727, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Healthy'),
#  Text(46.5, 345.9272727272727, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Failed'),
#  Text(62.0, 444.76363636363635, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]\nclass = Healthy'),
#  Text(77.5, 543.6, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Failed'),
#  Text(220.875, 741.2727272727273, 'Air Temp <= 310.95\ngini = 0.355\nsamples = 65\nvalue = [15, 50]\nclass = Healthy'),
#  Text(139.5, 642.4363636363637, 'Process Temp <= 1385.5\ngini = 0.105\nsamples = 36\nvalue = [2, 34]\nclass = Healthy'),
#  Text(108.5, 543.6, 'Rotational Speed <= 50.55\ngini = 0.061\nsamples = 32\nvalue = [1, 31]\nclass = Healthy'),
#  Text(93.0, 444.76363636363635, 'gini = 0.0\nsamples = 23\nvalue = [0, 23]\nclass = Healthy'),
#  Text(124.0, 444.76363636363635, 'Rotational Speed <= 50.9\ngini = 0.198\nsamples = 9\nvalue = [1, 8]\nclass = Healthy'),
#  Text(108.5, 345.9272727272727, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Failed'),
#  Text(139.5, 345.9272727272727, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]\nclass = Healthy'),
#  Text(170.5, 543.6, 'Torque <= 197.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]\nclass = Healthy'),
#  Text(155.0, 444.76363636363635, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Failed'),
#  Text(186.0, 444.76363636363635, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Healthy'),
#  Text(302.25, 642.4363636363637, 'Process Temp <= 1373.5\ngini = 0.495\nsamples = 29\nvalue = [13, 16]\nclass = Healthy'),
#  Text(248.0, 543.6, 'Rotational Speed <= 52.65\ngini = 0.388\nsamples = 19\nvalue = [5, 14]\nclass = Healthy'),
#  Text(217.0, 444.76363636363635, 'Air Temp <= 312.55\ngini = 0.305\nsamples = 16\nvalue = [3, 13]\nclass = Healthy'),
#  Text(201.5, 345.9272727272727, 'Process Temp <= 1359.5\ngini = 0.231\nsamples = 15\nvalue = [2, 13]\nclass = Healthy'),
#  Text(186.0, 247.09090909090912, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]\nclass = Healthy'),
#  Text(217.0, 247.09090909090912, 'Torque <= 64.0\ngini = 0.444\nsamples = 6\nvalue = [2, 4]\nclass = Healthy'),
#  Text(201.5, 148.25454545454545, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Healthy'),
#  Text(232.5, 148.25454545454545, 'Rotational Speed <= 50.35\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Failed'),
#  Text(217.0, 49.41818181818189, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Failed'),
#  Text(248.0, 49.41818181818189, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Healthy'),
#  Text(232.5, 345.9272727272727, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Failed'),
#  Text(279.0, 444.76363636363635, 'Air Temp <= 311.65\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Failed'),
#  Text(263.5, 345.9272727272727, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Failed'),
#  Text(294.5, 345.9272727272727, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Healthy'),
#  Text(356.5, 543.6, 'Process Temp <= 1394.0\ngini = 0.32\nsamples = 10\nvalue = [8, 2]\nclass = Failed'),
#  Text(341.0, 444.76363636363635, 'Torque <= 40.0\ngini = 0.198\nsamples = 9\nvalue = [8, 1]\nclass = Failed'),
#  Text(325.5, 345.9272727272727, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Healthy'),
#  Text(356.5, 345.9272727272727, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]\nclass = Failed'),
#  Text(372.0, 444.76363636363635, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Healthy'),
#  Text(507.625, 840.1090909090909, 'Torque <= 48.0\ngini = 0.178\nsamples = 142\nvalue = [14, 128]\nclass = Healthy'),
#  Text(418.5, 741.2727272727273, 'Rotational Speed <= 62.8\ngini = 0.42\nsamples = 20\nvalue = [6, 14]\nclass = Healthy'),
#  Text(403.0, 642.4363636363637, 'Air Temp <= 309.8\ngini = 0.496\nsamples = 11\nvalue = [6, 5]\nclass = Failed'),
#  Text(387.5, 543.6, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = Failed'),
#  Text(418.5, 543.6, 'Rotational Speed <= 59.0\ngini = 0.278\nsamples = 6\nvalue = [1, 5]\nclass = Healthy'),
#  Text(403.0, 444.76363636363635, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = Healthy'),
#  Text(434.0, 444.76363636363635, 'Air Temp <= 310.35\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Failed'),
#  Text(418.5, 345.9272727272727, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Healthy'),
#  Text(449.5, 345.9272727272727, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Failed'),
#  Text(434.0, 642.4363636363637, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]\nclass = Healthy'),
#  Text(596.75, 741.2727272727273, 'Torque <= 181.0\ngini = 0.123\nsamples = 122\nvalue = [8, 114]\nclass = Healthy'),
#  Text(558.0, 642.4363636363637, 'Torque <= 174.0\ngini = 0.212\nsamples = 58\nvalue = [7, 51]\nclass = Healthy'),
#  Text(527.0, 543.6, 'Air Temp <= 310.05\ngini = 0.137\nsamples = 54\nvalue = [4, 50]\nclass = Healthy'),
#  Text(511.5, 444.76363636363635, 'Rotational Speed <= 60.1\ngini = 0.332\nsamples = 19\nvalue = [4, 15]\nclass = Healthy'),
#  Text(480.5, 345.9272727272727, 'Air Temp <= 309.7\ngini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = Failed'),
#  Text(465.0, 247.09090909090912, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = Failed'),
#  Text(496.0, 247.09090909090912, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Healthy'),
#  Text(542.5, 345.9272727272727, 'Air Temp <= 309.9\ngini = 0.124\nsamples = 15\nvalue = [1, 14]\nclass = Healthy'),
#  Text(527.0, 247.09090909090912, 'gini = 0.0\nsamples = 14\nvalue = [0, 14]\nclass = Healthy'),
#  Text(558.0, 247.09090909090912, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Failed'),
#  Text(542.5, 444.76363636363635, 'gini = 0.0\nsamples = 35\nvalue = [0, 35]\nclass = Healthy'),
#  Text(589.0, 543.6, 'Rotational Speed <= 62.7\ngini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = Failed'),
#  Text(573.5, 444.76363636363635, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = Failed'),
#  Text(604.5, 444.76363636363635, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Healthy'),
#  Text(635.5, 642.4363636363637, 'Process Temp <= 1374.0\ngini = 0.031\nsamples = 64\nvalue = [1, 63]\nclass = Healthy'),
#  Text(620.0, 543.6, 'gini = 0.0\nsamples = 56\nvalue = [0, 56]\nclass = Healthy'),
#  Text(651.0, 543.6, 'Process Temp <= 1377.5\ngini = 0.219\nsamples = 8\nvalue = [1, 7]\nclass = Healthy'),
#  Text(635.5, 444.76363636363635, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Failed'),
#  Text(666.5, 444.76363636363635, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]\nclass = Healthy'),
#  Text(829.25, 938.9454545454546, 'Torque <= 200.0\ngini = 0.339\nsamples = 287\nvalue = [225, 62]\nclass = Failed'),
#  Text(728.5, 840.1090909090909, 'Rotational Speed <= 13.65\ngini = 0.2\nsamples = 231\nvalue = [205, 26]\nclass = Failed'),
#  Text(713.0, 741.2727272727273, 'gini = 0.0\nsamples = 16\nvalue = [0, 16]\nclass = Healthy'),
#  Text(744.0, 741.2727272727273, 'Rotational Speed <= 57.05\ngini = 0.089\nsamples = 215\nvalue = [205, 10]\nclass = Failed'),
#  Text(728.5, 642.4363636363637, 'Air Temp <= 306.35\ngini = 0.01\nsamples = 206\nvalue = [205, 1]\nclass = Failed'),
#  Text(713.0, 543.6, 'Rotational Speed <= 32.85\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Failed'),
#  Text(697.5, 444.76363636363635, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Healthy'),
#  Text(728.5, 444.76363636363635, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Failed'),
#  Text(744.0, 543.6, 'gini = 0.0\nsamples = 204\nvalue = [204, 0]\nclass = Failed'),
#  Text(759.5, 642.4363636363637, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]\nclass = Healthy'),
#  Text(930.0, 840.1090909090909, 'Air Temp <= 310.25\ngini = 0.459\nsamples = 56\nvalue = [20, 36]\nclass = Healthy'),
#  Text(844.75, 741.2727272727273, 'Torque <= 219.5\ngini = 0.488\nsamples = 26\nvalue = [15, 11]\nclass = Failed'),
#  Text(806.0, 642.4363636363637, 'Process Temp <= 1897.0\ngini = 0.36\nsamples = 17\nvalue = [13, 4]\nclass = Failed'),
#  Text(775.0, 543.6, 'Rotational Speed <= 56.1\ngini = 0.245\nsamples = 14\nvalue = [12, 2]\nclass = Failed'),
#  Text(759.5, 444.76363636363635, 'Torque <= 204.0\ngini = 0.142\nsamples = 13\nvalue = [12, 1]\nclass = Failed'),
#  Text(744.0, 345.9272727272727, 'Rotational Speed <= 31.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Failed'),
#  Text(728.5, 247.09090909090912, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Failed'),
#  Text(759.5, 247.09090909090912, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Healthy'),
#  Text(775.0, 345.9272727272727, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]\nclass = Failed'),
#  Text(790.5, 444.76363636363635, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Healthy'),
#  Text(837.0, 543.6, 'Air Temp <= 309.8\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Healthy'),
#  Text(821.5, 444.76363636363635, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Healthy'),
#  Text(852.5, 444.76363636363635, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Failed'),
#  Text(883.5, 642.4363636363637, 'Process Temp <= 1535.5\ngini = 0.346\nsamples = 9\nvalue = [2, 7]\nclass = Healthy'),
#  Text(868.0, 543.6, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = Healthy'),
#  Text(899.0, 543.6, 'Torque <= 225.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]\nclass = Failed'),
#  Text(883.5, 444.76363636363635, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Healthy'),
#  Text(914.5, 444.76363636363635, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Failed'),
#  Text(1015.25, 741.2727272727273, 'Process Temp <= 1524.5\ngini = 0.278\nsamples = 30\nvalue = [5, 25]\nclass = Healthy'),
#  Text(976.5, 642.4363636363637, 'Process Temp <= 1432.5\ngini = 0.117\nsamples = 16\nvalue = [1, 15]\nclass = Healthy'),
#  Text(961.0, 543.6, 'Process Temp <= 1423.0\ngini = 0.32\nsamples = 5\nvalue = [1, 4]\nclass = Healthy'),
#  Text(945.5, 444.76363636363635, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = Healthy'),
#  Text(976.5, 444.76363636363635, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Failed'),
#  Text(992.0, 543.6, 'gini = 0.0\nsamples = 11\nvalue = [0, 11]\nclass = Healthy'),
#  Text(1054.0, 642.4363636363637, 'Rotational Speed <= 37.65\ngini = 0.408\nsamples = 14\nvalue = [4, 10]\nclass = Healthy'),
#  Text(1023.0, 543.6, 'Torque <= 206.0\ngini = 0.18\nsamples = 10\nvalue = [1, 9]\nclass = Healthy'),
#  Text(1007.5, 444.76363636363635, 'Process Temp <= 1838.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Failed'),
#  Text(992.0, 345.9272727272727, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Failed'),
#  Text(1023.0, 345.9272727272727, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Healthy'),
#  Text(1038.5, 444.76363636363635, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]\nclass = Healthy'),
#  Text(1085.0, 543.6, 'Air Temp <= 310.95\ngini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = Failed'),
#  Text(1069.5, 444.76363636363635, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Healthy'),
#  Text(1100.5, 444.76363636363635, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = Failed')]

# %%
plot_confusion_matrix(dtc_fnf, x_plain_test, y_plain_test)
dtc_fnf_pred = dtc_fnf.predict(x_plain_test)
print("Accuracy of FNF: ", accuracy_score(dtc_fnf_pred, y_plain_test) * 100 , "%")
# Out:
# Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
# Accuracy of FNF:  87.89237668161435 %

# %%
explainer = shap.KernelExplainer(dtc_hdf.predict_proba, x_hdf_train)
shap_values = explainer.shap_values(x_hdf_train)
shap.summary_plot(shap_values, x_hdf_test, plot_type = 'bar', class_names = dtc_hdf.classes_)
# Out:
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# Using 107 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
#   0%|          | 0/107 [00:00<?, ?it/s]
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names

# %%
explainer = shap.KernelExplainer(dtc_fnf.predict_proba, x_plain_train)
shap_values = explainer.shap_values(x_plain_train)
shap.summary_plot(shap_values, x_plain_test, plot_type = 'bar', class_names = dtc_fnf.classes_)
# Out:
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# Using 518 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
#   0%|          | 0/518 [00:00<?, ?it/s]
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# ...
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names

# %%
explainer = shap.KernelExplainer(dtc_final.predict_proba, x_train)
shap_values = explainer.shap_values(x_train)
shap.summary_plot(shap_values, x_test, plot_type = 'bar', class_names = dtc_final.classes_)
# Out:
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# Using 518 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
#   0%|          | 0/518 [00:00<?, ?it/s]
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# ...
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names

# %%
explainer = shap.KernelExplainer(dtc_pwf.predict_proba, x_pwf_train)
shap_values = explainer.shap_values(x_pwf_train)
shap.summary_plot(shap_values, x_pwf_test, plot_type = 'bar', class_names = dtc_pwf.classes_)
# Out:
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# Using 133 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
#   0%|          | 0/133 [00:00<?, ?it/s]
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names

# %%
explainer = shap.KernelExplainer(dtc_osf.predict_proba, x_osf_train)
shap_values = explainer.shap_values(x_osf_train)
shap.summary_plot(shap_values, x_osf_test, plot_type = 'bar', class_names = dtc_osf.classes_)
# Out:
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# Using 149 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
#   0%|          | 0/149 [00:00<?, ?it/s]
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names

# %%
explainer = shap.KernelExplainer(twf_clf.predict_proba, x_twf_train)
shap_values = explainer.shap_values(x_twf_train)
shap.summary_plot(shap_values, x_twf_test, plot_type = 'bar', class_names = twf_clf.classes_)
# Out:
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   0%|          | 0/72 [00:00<?, ?it/s]
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names

# %%
explainer = shap.KernelExplainer(dtc_final.predict_proba, x_train)
shap_values = explainer.shap_values(x_train)
shap.plots.beeswarm(shap_values)
# Out:
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# Using 518 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
#   0%|          | 0/518 [00:00<?, ?it/s]
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# ...
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-59-6963f1093283> in <module>()
#       1 explainer = shap.KernelExplainer(dtc_final.predict_proba, x_train)
#       2 shap_values = explainer.shap_values(x_train)
# ----> 3 shap.plots.beeswarm(shap_values)
#
# /usr/local/lib/python3.7/dist-packages/shap/plots/_beeswarm.py in beeswarm(shap_values, max_display, order, clustering, cluster_threshold, color, axis_color, alpha, show, log_scale, color_bar, plot_size, color_bar_label)
#      65         #     out_names = shap_exp.output_names
#      66
# ---> 67     order = convert_ordering(order, values)
#      68
#      69
#
# UnboundLocalError: local variable 'values' referenced before assignment
